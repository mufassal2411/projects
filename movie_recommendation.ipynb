# %% [markdown]
# <a href="https://colab.research.google.com/github/mufassal2411/projects/blob/main/movie_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **First of all we will going to import all the required libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#read csv file
df = pd.read_csv('/content/movie.csv.zip')

# first few rows of dataset
df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df.shape
# Out:
# (27278, 3)

# %%
# drop genres column
df.drop(['genres'],axis=1,inplace=True)

# %% [markdown]
# **We need to import our another dataset in which we have ratings for the movie**

# %%
# import rating dataset
rating = pd.read_csv("/content/rating.csv.zip")

# columns
rating.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
# we need user id, movie id and rating
rating = rating.loc[:,["userId","movieId","rating"]]
rating.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
#then merge movie and rating data
df = pd.merge(df,rating)

# %%
df.head()
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       3     4.0
# 1        1  Toy Story (1995)       6     5.0
# 2        1  Toy Story (1995)       8     4.0
# 3        1  Toy Story (1995)      10     4.0
# 4        1  Toy Story (1995)      11     4.5

# %% [markdown]
# **As noted here one user has rated one or more than one movie. This means that one movie has been rated by more than one user**.

# %%
df.shape
# Out:
# (20000263, 4)

# %% [markdown]
# **In our kaggle kernel,we don't have much memory so we have to subset our dataset**

# %%
df = df.iloc[:1000000]

# %%
df.shape
# Out:
# (1000000, 4)
